# %%
"""
A subarray is a contiguous part of an array.
Order matters, and the elements must be contiguous (next to each other).
The number of subarrays in an array of length n is n*(n+1)/2
For example, Consider the array [1, 2, 3, 4], There are 10 non-empty sub-arrays. The subarrays are:

(1), (2), (3), (4), (1,2), (2,3), (3,4), (1,2,3), (2,3,4), and (1,2,3,4) """

# %%
""" Given an array of N integers and a number K, 
the task is to find the number of subarrays such that all elements are greater than K in it. 

Examples: 

Input: a[] = {3, 4, 5, 6, 7, 2, 10, 11}, K = 5 
Output: 6 
The possible subarrays are {6}, {7}, {6, 7}, {10}, {11} and {10, 11}.

Input: a[] = {8, 25, 10, 19, 19, 18, 20, 11, 18}, K = 13 
Output: 12 """

# %% [markdown]
# <!-- Input: a[] = {3, 4, 5, 6, 7, 2, 10, 11}, K = 5 find the subarrays greater than K
# Output: 6
# The possible subarrays are {6}, {7}, {6, 7}, {10}, {11} and {10, 11}. Subarray example.. contiguous array: n*(n+1)/2 -->

# %%
""" A subsequence is a sequence that can be derived from another sequence by removing zero or more elements,
without changing the order of the remaining elements.

(1), (2), (3), (4), (1,2), (1,3),(1,4), (2,3), (2,4), (3,4), (1,2,3), (1,2,4), (1,3,4), (2,3,4), (1,2,3,4). """

# %%
""" Given a binary array, the task is to find the size of the largest sub_sequence 
which having equal number of zeros and one. 

Examples : 

Input : arr[] = { 1, 0, 0, 1, 0, 0, 0, 1 } 
Output: 6 (indexes: 0,2,3,4,5,7)

Input : arr[] = { 0, 0, 1, 1, 1, 1, 1, 0, 0 } """

# %%
""" A subset is any combination of elements from an array or set, including the empty set and the set itself.
Order does not matter.
A subset can be created by picking or skipping any element from the array, and the elements don’t have to be contiguous.
If the original array has n elements, the total number of subsets is 2^n """

# %%
"""Write a program takes an array of integers as input and
 calculates the size of a subset that can be formed from the array.
   This subset should consist of non-negative integers.
and as many negative integers as possible without making the sum of the subset negative.

 the Input: arr[] = {5, -7, 0, -5, -3, -1}

Non-negative numbers: 5, 0 → Sum = 5.
Sorted negative numbers: -1, -3, -5, -7.
Add -1 → Sum = 4.
Add -3 → Sum = 1.
Add -5 → Sum = -4 (which violates the condition).
So, the largest subset we can pick is {5, 0, -1, -3} with a sum of 1 and size 4.
Output: 4

Example 2:
Input: arr[] = {1, -4, -2, -3}

Non-negative number: 1 → Sum = 1.
Sorted negative numbers: -2, -3, -4.
Adding any negative number would make the sum negative.
So, the largest subset is {1} with a sum of 1 and size 1.


n = int(input())
arr = list(map(int, input().split()))

pos_subset = [x for x in arr if x >= 0]
neg_subset = sorted([x for x in arr if x < 0], reverse=True) #sorts highest to lowest for ex -1,-2,-3

sum_subset = sum(pos_subset)
subset_size = len(pos_subset)

for num in neg_subset:
    if sum_subset + num >= 0:
        sum_subset += num
        subset_size += 1
    else:
        break

print(subset_size) """

# %% [markdown]
# <!-- A subset is any combination of elements from an array or set, including the empty set and the set itself.
# Order does not matter.
# A subset can be created by picking or skipping any element from the array, and the elements don’t have to be contiguous.
# If the original array has n elements, the total number of subsets is 2^n
#
#
# find largest subset array size which is greater than or equal to zero but non negative
#
# Input: arr[] = {5, -7, 0, -5, -3, -1}
#
# Non-negative numbers: 5, 0 → Sum = 5.
# Sorted negative numbers: -1, -3, -5, -7.
# Add -1 → Sum = 4.
# Add -3 → Sum = 1.
# Add -5 → Sum = -4 (which violates the condition).
# So, the largest subset we can pick is {5, 0, -1, -3} with a sum of 1 and size 4.
# Output: 4
#  -->

# %%
""" import java.util.Arrays;
import java.util.Scanner;

public class SubsetSizeCalculator {
    public static void main(String[] args) {
        Scanner scanner = new Scanner(System.in);

        // Read input size
        int n = scanner.nextInt();

        // Read the array
        int[] arr = new int[n];
        for (int i = 0; i < n; i++) {
            arr[i] = scanner.nextInt();
        }

        // Create arrays for positive and negative numbers
        int[] posSubset = new int[n];
        int[] negSubset = new int[n];
        int posCount = 0, negCount = 0;

        // Separate positive and negative numbers
        for (int num : arr) {
            if (num >= 0) {
                posSubset[posCount++] = num;
            } else {
                negSubset[negCount++] = num;
            }
        }

        // Sort negative subset in reverse order
        Arrays.sort(negSubset, 0, negCount);
        reverseArray(negSubset, negCount);

        // Calculate the sum of the positive subset
        int sumSubset = 0;
        for (int i = 0; i < posCount; i++) {
            sumSubset += posSubset[i];
        }

        int subsetSize = posCount;

        // Process negative numbers
        for (int i = 0; i < negCount; i++) {
            if (sumSubset + negSubset[i] >= 0) {
                sumSubset += negSubset[i];
                subsetSize++;
            } else {
                break;
            }
        }

        // Output the result
        System.out.println(subsetSize);
    }

    private static void reverseArray(int[] arr, int length) {
        for (int i = 0; i < length / 2; i++) {
            int temp = arr[i];
            arr[i] = arr[length - 1 - i];
            arr[length - 1 - i] = temp;
        }
    }
} """
